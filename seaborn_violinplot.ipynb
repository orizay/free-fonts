# %% [markdown]
# <a href="https://colab.research.google.com/github/orizay/free-fonts/blob/master/seaborn_violinplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid", palette="pastel", color_codes=True)

# %matplotlib inline

# %%
# Load the example tips dataset
tips = sns.load_dataset("tips")
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
tips.sample()
# Out:
#      total_bill   tip     sex smoker   day   time  size
# 134       18.26  3.25  Female     No  Thur  Lunch     2

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='day',y='total_bill',data=tips)

# %%
plt.figure(figsize=(10,8))
sns.violinplot(x='day',y='total_bill',data=tips)

# %%
plt.figure(figsize=(10,8))
sns.violinplot(x='day',y='total_bill',data=tips,hue='smoker')

# %%
plt.figure(figsize=(10,8))
sns.violinplot(x='time',y='tip',data=tips,order=['Dinner','Lunch'])

# %%
tips['weekend'] = tips['day'].isin(['Sta','Sun'])
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  weekend
# 0       16.99  1.01  Female     No  Sun  Dinner     2     True
# 1       10.34  1.66    Male     No  Sun  Dinner     3     True
# 2       21.01  3.50    Male     No  Sun  Dinner     3     True
# 3       23.68  3.31    Male     No  Sun  Dinner     2     True
# 4       24.59  3.61  Female     No  Sun  Dinner     4     True

# %%
plt.figure(figsize=(10,8))
sns.violinplot(x='day',y='total_bill',hue='weekend',data=tips,dodge=False)

# %%
# Draw a nested violinplot and split the violins for easier comparison
plt.figure(figsize=(10,8))
sns.violinplot(x="day", y="total_bill", hue="smoker",
               split=True, inner="quart",
               palette={"Yes": "y", "No": "b"},
               data=tips)
sns.despine(left=True) # 테두리 없애는 옵션
